# %%
import numpy as np
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv(r"F:\2019\Medilab\survey.csv")
df.head()
# Out:
#             Timestamp  Age  Gender        Street           City    District  \
# 0    08-05-2019 08:46   22  Female    Mannathoor            NaN   Ernakulam
# 1    08-05-2019 08:57   22  Female     Varapuzha            NaN   Ernakulam
# 2  9/13/2019 21:53:34   23  Female    Mannathoor      Pampakuda   Ernakulam
# 3  9/13/2019 22:42:07   24  Female  Vazhikkadavu       Nilambur  Malappuram
# 4  9/13/2019 22:45:27   22  Female    Mannathoor  Koothatukulam   Ernakulam
#
#   Occupation If other, specify occupation  \
# 0    Student                          NaN
# 1    student                          NaN
# 2    Student                          NaN
# 3    Student                          NaN
# 4    Student                          NaN
#
#   How many hours do you sit and work or study? Blood Group    ...      \
# 0                                          NaN          A+    ...
# 1                                          NaN  O positive    ...
# ...

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file("output.html")
